# %% [markdown]
# ## MY FIRST NOTEBOOK

# %%
print("Hello world")
# Out:
# Hello world

# %%
# This is a comment

# %% [markdown]
# # MARKDOWN EXAMPLES

# %% [markdown]
# # Heading level 1
# ## heading level 2
# #### heading level 4
#
# This is simple markdown text

# %% [markdown]
# *this text is in italic*
#
# **this text is bold**
#
# ***this text is in italic and bold***
#
# <u> this text is underlined </u>

# %% [markdown]
# $x+y=10$
#
#
# the equation is given as:
# $$x+y=10$$

# %% [markdown]
# This is line 1
# This is line 2
#
# This is line 1 \
# This is line 2
#
# This is line 1
# This is line 2 (I added two spaces after line 1 above)

# %% [markdown]
# [Link to Anaconda](http://anaconda.org)
#
# <

# %% [markdown]
# 1. list-item1
# 2. list-item2 \
#     2.1 subitem1 \
#     2.2 subitem2
# 3. list-item3
#
# - one
# - two
# - three
# * four
# + five

# %% [markdown]
#     here is a code block.
#     another line
#
# here is a `backtick span of code`

# %% [markdown]
# if we wish to print a star (but it has special meaning in Markdown), we have to escape it: \*
#
#     escaping means to write a \ before the char that you want to print

# %% [markdown]
# THE END
